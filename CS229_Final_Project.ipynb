# %%
import yfinance as yf
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import cvxopt as opt
from cvxopt import blas, solvers
import pandas as pd
import random

import plotly
import cufflinks
plotly.__version__
from datetime import datetime, timedelta

## helper functions

"""
This grabs the start date given the end date and how
many days back you want to go
Input: string, int
Return: string
"""
def date_before_x_days(end_date, days_back):
  start_date = datetime.strptime(end_date, '%Y-%m-%d') - timedelta(days=days_back)
  return start_date.strftime('%Y-%m-%d')


"""
This deletes any stocks that doesn't have data from
our data set. Updates stocks left, data set, and the
stock count.
Input: list<string>, dataframe, int
Return: list<string>, dataframe, int
"""
def clean_data(stocks, dataset, stock_count):
  no_vals = []  ## stocks that don't have data
  for stock in stocks:
    d = dataset["Close"][stock].to_list()
    if any(np.isnan(i) for i in d):
      no_vals.append(stock)

  stock_count -= len(no_vals)  ## eliminating empty stock from count

  for stock in no_vals:
    stocks.remove(stock)  ## eliminating empty stock from STOCKS
    dataset = dataset.drop(columns=stock, level = 1)  ## dropping these stocks from our data

  return stocks, dataset, stock_count


"""
Given a dataset, we construct a dictionary representation
of our feature matrix to ensure the features are in the
same column. They are also labeled for simplicity
Outmost key is stock name
Inner key is feature name
Input: list<string>, dataframe, int
Return: dict<string, dict<string, int>>
"""
def make_feature_dict(stocks, dataset, window):
  X = {stock : {"const" : 1} for stock in stocks}  ## this will be our data

  ## Adj Close, Close, High, Low, Open, Volume (added here) (these are for a single day)
  for stock in stocks:
    X[stock]["Adj Close"] = dataset["Adj Close"][stock][-1]
    X[stock]["Close"] = dataset["Close"][stock][-1]
    X[stock]["High"] = dataset["High"][stock][-1]
    X[stock]["Low"] = dataset["Low"][stock][-1]
    X[stock]["Open"] = dataset["Open"][stock][-1]
    X[stock]["Volume"] = dataset["Volume"][stock][-1]

  ## SMA, Volatility, EMA, RSI (over last WINDOW_SIZE days) (these are more long-term information)
  for stock in stocks:
    g = dataset["Adj Close"][stock]  ## I used Adjusted Close for stability

    X[stock]["SMA"] = g.rolling(window=window).mean().iloc[-1]
    f = np.log(g / g.shift(1))
    X[stock]["Volatility"] = np.std(f[-window:])  ## this is how you calculate volatility
    X[stock]["EMA"] = g.ewm(span=window, adjust=False).mean().iloc[-1]

    delta = g.diff(1)
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))

    X[stock]["RSI"] = rsi.iloc[-1]
  return X


"""
Turns the Feature Matrix in Dictionary Form into an actual numpy matrix
"""
def dict_to_matrix(X):
  X_matrix = []
  for stock, features in X.items():
    temp = []

    for name, feature in features.items():
      temp.append(feature)

    X_matrix.append(temp)

  return np.array(X_matrix)


"""
Obtains the Y vector for the given stocks on the end_date
Input: string, int, list<string>
Return: list<int>
"""
def obtain_y(end_date, stocks, days_back=7):
  start_date = date_before_x_days(end_date, days_back)
  y_data = yf.download(stocks, start=start_date, end=end_date)["Adj Close"].iloc[-1]
  return np.array([y_data[stock] for stock in stocks])

# %%
#######################################################################
## OBTAIN ALL COMPONENT STOCK FROM S&P 500 AND CREATE GLOBAL VARIABLES
#######################################################################
from sklearn.model_selection import train_test_split
URL = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
sp500_data = pd.read_html(URL)[0]

ALL_STOCKS = sp500_data['Symbol'].to_list()  ## grab random sample of this??
ALL_STOCKS = ALL_STOCKS[:50]
#ALL_STOCKS = random.sample(ALL_STOCKS, 100)
ALL_STOCK_COUNT = len(ALL_STOCKS)
#print(ALL_STOCK_COUNT)

# Replacing variable names (mandatory) # Cynthia added
TESTING_STOCKS = ALL_STOCKS
TRAINING_STOCKS = ALL_STOCKS

WINDOW_SIZE = 502  ## ALL THE DATA
GO_BACK = 50  ## DATA USED FOR ML


TRAINING_END_DATE = "2013-12-31"  ## training matrix data from this time period
TRAINING_START_DATE = date_before_x_days(TRAINING_END_DATE, WINDOW_SIZE)

TESTING_END_DATE = "2018-12-31"  ## testing matrix data from this time period
TESTING_START_DATE = date_before_x_days(TESTING_END_DATE, WINDOW_SIZE)


TRAINING_PREDICTION_DATE = "2018-12-31"
TESTING_PREDICTION_DATE = "2023-12-31"

# %%
################################################################################
# OBTAIN DATA
################################################################################

## Training data for 2013. Used to predict in 2018
training_data = yf.download(ALL_STOCKS, start=TRAINING_START_DATE, end=TRAINING_END_DATE)

## Testing data for 2018. Used to predict in 2023
testing_data = yf.download(ALL_STOCKS, start=TESTING_START_DATE, end=TESTING_END_DATE)
# Out:
# [*********************100%%**********************]  50 of 50 completed
# ERROR:yfinance:
# 2 Failed downloads:
# ERROR:yfinance:['ABNB', 'ANET']: Exception("%ticker%: Data doesn't exist for startDate = 1345089600, endDate = 1388466000")
# [*********************100%%**********************]  50 of 50 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABNB']: Exception("%ticker%: Data doesn't exist for startDate = 1502856000, endDate = 1546232400")

# %%
################################################################################
# CLEANING DATA
################################################################################
ALL_STOCKS, training_data, ALL_STOCK_COUNT = clean_data(ALL_STOCKS,
                                                        training_data,
                                                        ALL_STOCK_COUNT)
print(ALL_STOCK_COUNT)
print(len(ALL_STOCKS))

ALL_STOCKS, testing_data, ALL_STOCK_COUNT = clean_data(ALL_STOCKS,
                                                        testing_data,
                                                        ALL_STOCK_COUNT)

print(ALL_STOCK_COUNT)
print(len(ALL_STOCKS))

ALL_STOCKS, training_data, ALL_STOCK_COUNT = clean_data(ALL_STOCKS,
                                                        training_data,
                                                        ALL_STOCK_COUNT)
print(ALL_STOCK_COUNT)
print(len(ALL_STOCKS))
# Out:
# 46
# 46
# 46
# 46
# 46
# 46

# %%
################################################################################
# POPULATE FEATURE MATRIX FOR TRAINING AND TESTING IN DICTIONARY FORM
################################################################################
training_X_dict = make_feature_dict(ALL_STOCKS,
                                    training_data,
                                    GO_BACK)

testing_X_dict = make_feature_dict(ALL_STOCKS,
                                   testing_data,
                                   GO_BACK)

# %%
################################################################################
# TURN FEATURE MATRIX IN DICTIONARY FORM INTO A MATRIX
################################################################################
training_X = dict_to_matrix(training_X_dict)

testing_X = dict_to_matrix(testing_X_dict)

# %%
################################################################################
# NORMALIZE THE FEATURE MATRIX FOR TRAINING AND TESTING
################################################################################
n = training_X.shape[1]
feature_norms = np.zeros(n)

for i in range(n):
  col = training_X[:, i]
  feature_norms[i] = np.linalg.norm(col)

training_X = training_X / feature_norms
testing_X = testing_X / feature_norms

# %%
################################################################################
# OBTAIN Y VECTOR FOR TRAINING AND TESTING
################################################################################
training_y = obtain_y(TRAINING_PREDICTION_DATE, ALL_STOCKS)

testing_y = obtain_y(TESTING_PREDICTION_DATE, ALL_STOCKS)
# Out:
# [*********************100%%**********************]  46 of 46 completed
# [*********************100%%**********************]  46 of 46 completed

# %%
##########################################################################################################
# HELPER FUNCTIONS: OBTAIN OPTIMAL WEIGHTS USING RIDGE and HELPER FUNCTION FOR CALCULATING LOSS, OUR METHOD
##########################################################################################################
def ridge_obtain_thetas(training_X, training_y, lmbda = 2, iterations = 10000000, eps = 1e-3, alpha = 1e-5):
  cur_weights = np.zeros(training_X.shape[1])
  for _ in range(iterations):
    old_weights = cur_weights
    cur_weights = old_weights - alpha * (training_X.T.dot(training_X.dot(old_weights) - training_y) + lmbda * old_weights)
    if np.linalg.norm(cur_weights - old_weights) < eps:
      break
  else:
    print("increase iterations")

  theta = cur_weights
  return theta

# calculate loss
def calculate_loss(x, y, thetas, lmbda = 2):
  return (x.dot(thetas) - y).T.dot(x.dot(thetas) - y) + lmbda * thetas.T.dot(thetas)

# %%
################################################################################
# EVALUATING LOSS ON TESTING DATA SET (OUR METHOD)
################################################################################
print("Loss on testing data set (ridge regression model)")
theta = ridge_obtain_thetas(training_X, training_y)

print(1 / len(testing_y) * calculate_loss(testing_X, testing_y, theta, lmbda = 2))
print(1 / len(testing_y) * calculate_loss(testing_X, testing_y, theta, lmbda = 0))
# Out:
# Loss on testing data set (ridge regression model)
# 11162.039302055455
# 10257.803461137175

# %%
#####################################################################
# EVALUATING LOSS ON TESTING DATA SET (OPPOSING METHOD) (1-Year SMA)
#####################################################################
model_preds = []

NUM_YEARS = 5

for stock in TESTING_STOCKS:

  ## clip amount of data we need. Makes indexing easier
  g = testing_data["Adj Close"][stock][-252:]

  smas = np.zeros(12)
  adj_c = np.zeros(12)
  for i in range(12):
    g_temp = g[i * 21: (i+1) * 21]
    adj_c[i] = g_temp[0]
    smas[i] = g_temp.rolling(window=21).mean().iloc[-1]

  returns = (smas - adj_c) / adj_c
  ret = np.sum(returns)
  model_preds.append(((1 + ret) ** 5 ) * testing_data["Adj Close"][stock][-1])

print(model_preds)
model_preds = np.array(model_preds)

print("Loss on testing data set (1-year SMA, Method 1)")
print(1 / len(testing_y) * (model_preds - testing_y).T.dot(model_preds - testing_y))
# Out:
# [149.72341716927312, 40.98436365732366, 110.42369091173016, 210.3562918276093, 551.6506898855238, 238.74204367855484, 15.99744792126171, 48.4536788168675, 113.97234157578417, 206.38070755592554, 133.23640626842814, 89.06899297908865, 49.458113899996086, 530.640757702934, 30.569621773124325, 45.244787465945, 73.10469247046505, 77.05483832872517, 26.05461519526012, 200.6916021288991, 3.9820154481043692, 65.7042579059782, 7.913103141894963, 53.63360776703235, 130.3364004820943, 15.07546288512531, 169.7823818533614, 66.92532240370474, 37.79169022217633, 123.37024385984675, 267.1702539007744, 45.72507798744729, 112.6631362863609, 268.8133052166404, 225.66622251460063, 16.81326729229883, 64.45738334817327, 18.503274403005094, 59.49797740333652, 18.00031312485766, 67.46466926388636, 97.0236893572658, 76.89352198455839, 13.5308763254299, 83.32527095156487, 469.3224394822941]
# Loss on testing data set (1-year SMA, Method 1)
# 8848.011336285965

# %%
################################################################################
# Generating expected returns vector of TESTING using ML
################################################################################

proj = testing_X.dot(theta)
adj = testing_X[:, 1] * feature_norms[1]  ## un-normalizing the matrix
expected_returns_ridge = (proj - adj) / adj

actual = (testing_y - adj) / adj

print(np.power(1 / len(actual) * np.linalg.norm(actual - expected_returns_ridge) + 1, 1 / 5) - 1)
## We are off, on average, by 2.49% per year per stock when checking against testing
## Update: we are off, on average by 1.91% per year per stock when checking against testing
# Out:
# 0.040512842367158575

# %%
################################################################################
# (METHOD 1)
# Generating expected returns vector of testing stocks using 1-year SMA
################################################################################

expected_returns_SMA_1 = [] # Our goal is to populate this vector

NUM_YEARS = 5

for stock in ALL_STOCKS:

  ## clip amount of data we need. Makes indexing easier
  g = testing_data["Adj Close"][stock][-252:]

  smas = np.zeros(12)
  adj_c = np.zeros(12)
  for i in range(12):
    g_temp = g[i * 21: (i+1) * 21]
    adj_c[i] = g_temp[0]
    smas[i] = g_temp.rolling(window=21).mean().iloc[-1]

  returns = (smas - adj_c) / adj_c
  ret = np.sum(returns)

  expected_returns_SMA_1.append((1 + ret) ** NUM_YEARS - 1)

expected_returns_SMA_1 = np.array(expected_returns_SMA_1)
# print(expected_returns_SMA)

print(np.power(1 / len(actual) * np.linalg.norm(actual - expected_returns_SMA_1) + 1, 1 / 5) - 1)
## We are off, on average, by 2.66% per year per stock when checking against testing
## Update: We are off, on average, by 2.40% per year per stock when checking against testing
# Out:
# 0.04155810490630607

# %%
################################################################################
# (METHOD 2)
# Generating expected returns vector of testing stocks using 1-year SMA
################################################################################

import numpy as np

expected_returns_SMA_2 = [] # Our goal is to populate this vector

NUM_YEARS = 5
FACTOR =  1 / NUM_YEARS

for stock in ALL_STOCKS:

  g = testing_data["Adj Close"][stock][-252:]

  # Method 2: You could get the average adj_close_start from first 5 values
  adj_close_start = np.mean(g[0:5])

  sma = g.rolling(window=252).mean().iloc[-1]

  # Gets the return 251 (one year's market days) days before each end date
  ret = ( sma - adj_close_start ) / adj_close_start

  expected_returns_SMA_2.append((1 + ret) ** NUM_YEARS - 1)

expected_returns_SMA_2 = np.array(expected_returns_SMA_2)
# print(expected_returns_SMA)

print(np.power(1 / len(actual) * np.linalg.norm(actual - expected_returns_SMA_2) + 1, FACTOR) - 1)
## We are off, on average, by 2.70% per year per stock when checking against testing
## Update: We are off, on average, by 2.65% per year per stock when checking against testing
# Out:
# 0.040657663092243945

# %%
################################################################################
# Get Predicted Returns for a 50 day time span
################################################################################
predicted_prices = []

tr_data = training_data
te_data = testing_data

start_date = date_before_x_days(TRAINING_PREDICTION_DATE, 100)
training_y_data = yf.download(ALL_STOCKS, start=start_date, end=TRAINING_PREDICTION_DATE)["Adj Close"]

for i in range(GO_BACK):

  training_X_dict = make_feature_dict(ALL_STOCKS, tr_data, GO_BACK)

  testing_X_dict = make_feature_dict(ALL_STOCKS, te_data, GO_BACK)

  training_X = dict_to_matrix(training_X_dict)

  testing_X = dict_to_matrix(testing_X_dict)

  n = training_X.shape[1]
  feature_norms = np.zeros(n)

  for i in range(n):
    col = training_X[:, i]
    feature_norms[i] = np.linalg.norm(col)

  training_X = training_X / feature_norms
  testing_X = testing_X / feature_norms

  training_y_unordered = training_y_data.iloc[-i-1]
  training_y = np.array([training_y_unordered[stock] for stock in ALL_STOCKS])

  theta = ridge_obtain_thetas(training_X, training_y)

  predicted_prices.append(testing_X.dot(theta))

  tr_data = tr_data[:-1]
  te_data = te_data[:-1]

  if i + 1 % 5 == 0:
    print(i)

predicted_prices = predicted_prices[::-1]
predicted_prices = np.array(predicted_prices)
print(predicted_prices.shape) # 50 x 96?
# Out:
# [*********************100%%**********************]  46 of 46 completed
# (50, 46)

# %%
print(predicted_prices)
#predicted_prices = predicted_returns
# Out:
# [[204.95808076  65.31166681  86.67016644 ...  38.06394102 107.24397838
#   170.94963569]
#  [204.03326994  64.43693749  85.51740952 ...  38.10106872 107.90923778
#   169.02958547]
#  [202.60510801  63.45886869  84.52495229 ...  38.07671814 108.70500784
#   166.11722563]
#  ...
#  [184.97354491  62.06019972  84.86350793 ...  38.79528965 102.49351143
#   150.68010669]
#  [188.10034361  62.33691935  86.15321257 ...  38.84876891 103.17555304
#   152.23965163]
#  [189.69292372  62.36782274  86.90240381 ...  39.01959176 103.95312087
#   153.39396309]]

# %%
################################################################################
# Calculate HISTORICAL Covariance Matrix
################################################################################
# Helper function
GO_BACK = 50  ## DATA USED FOR ML

def generate_daily_return_vec(closing_prices_vec):
  daily_returns_vec = []
  for i in range(1, len(closing_prices_vec)):
    daily_return = ((closing_prices_vec[i] - closing_prices_vec[i-1]) / closing_prices_vec[i-1]) * 100
    daily_returns_vec.append(daily_return)
  return daily_returns_vec

# Helper function to calculate the covariance between two assets
def calculate_covariance_hist(asset1, asset2):
  closing_prices_asset1 = testing_data["Adj Close"][asset1][-GO_BACK:]
  closing_prices_asset2 = testing_data["Adj Close"][asset2][-GO_BACK:]
  daily_returns_asset1, daily_returns_asset2 = generate_daily_return_vec(closing_prices_asset1), generate_daily_return_vec(closing_prices_asset2)
  sample_means_1, sample_means_2 = np.mean(daily_returns_asset1), np.mean(daily_returns_asset2)
  # Subtract the sample means from each element of the respective daily returns vectors
  deviation_1, deviation_2 = daily_returns_asset1 - sample_means_1, daily_returns_asset2 - sample_means_2
  # Next step
  un_normalized_covariance = np.sum(deviation_1 * deviation_2) # element-wise multiplication
  covariance = (1 / (GO_BACK - 1)) * un_normalized_covariance # Check that N - 1 is correct
  return covariance

# Function to calculate covariance matrix given a vector of stocks
def calculate_covariance_matrix_hist(stocks): #param: vector of stocks
  num_stocks = len(stocks)
  covariance_matrix = np.zeros((num_stocks, num_stocks))
  for i in range(num_stocks):
    asset1 = stocks[i]
    for j in range(num_stocks):
      asset2 = stocks[j]
      covariance_matrix[i, j] = calculate_covariance_hist(asset1, asset2)
  return covariance_matrix

covariance_matrix_historical = calculate_covariance_matrix_hist(TESTING_STOCKS)
print(covariance_matrix_historical)
# Out:
# [[ 3.49958807  2.04429075  2.76426011 ...  1.83309898  0.84261964
#    4.33507654]
#  [ 2.04429075  5.13812004  2.04610422 ...  1.34507494 -0.06389754
#    4.1556187 ]
#  [ 2.76426011  2.04610422  3.41017524 ...  1.78854287  0.51497066
#    4.37688708]
#  ...
#  [ 1.83309898  1.34507494  1.78854287 ...  3.61313956  0.77917841
#    3.13450027]
#  [ 0.84261964 -0.06389754  0.51497066 ...  0.77917841  2.24102151
#    0.05459386]
#  [ 4.33507654  4.1556187   4.37688708 ...  3.13450027  0.05459386
#   11.07585884]]

# %%
################################################################################
# Calculate PROJECTED Covariance Matrix
################################################################################
# ret_vec_1 = predicted_returns[asset1]
# ret_vec_2 = predicted_returns[asset2]

# Get returns vector from predicted returns (030724)
def get_prices_vector(index, predicted_returns):
  ret_vec = []
  for row in predicted_returns:
    val = row[index]
    ret_vec.append(val)
  return ret_vec

# Inputs are predicted prices vectors of 50 days
def calculate_covariance_pred(daily_prices_asset1, daily_prices_asset2):
  N = len(daily_prices_asset1)
  daily_returns_asset1, daily_returns_asset2 = generate_daily_return_vec(daily_prices_asset1), generate_daily_return_vec(daily_prices_asset2)
  sample_means_1, sample_means_2 = np.mean(daily_returns_asset1), np.mean(daily_returns_asset2)
  # Subtract the sample means from each element of the respective daily returns vectors
  deviation_1, deviation_2 = daily_returns_asset1 - sample_means_1, daily_returns_asset2 - sample_means_2
  # Next step
  un_normalized_covariance = np.sum(deviation_1 * deviation_2) # element-wise multiplication
  covariance = (1 / (N - 1)) * un_normalized_covariance # Check that N - 1 is correct
  return covariance

# Getting predicted covariance matrix
def calculate_covariance_matrix_pred(stocks): #param: vector of stocks (TESTING_STOCKS)
  num_stocks = len(stocks)
  covariance_matrix = np.zeros((num_stocks, num_stocks))
  for i in range(num_stocks):
    asset1 = stocks[i]
    for j in range(num_stocks):
      asset2 = stocks[j]
      # New new stuff (031424)
      ret_vec_1 = get_prices_vector(i, predicted_prices)
      ret_vec_2 = get_prices_vector(j, predicted_prices)
      # Helper function above: calculate_covariance_pred
      covariance_matrix[i, j] = calculate_covariance_pred(ret_vec_1, ret_vec_2)
  return covariance_matrix

covariance_matrix_pred = calculate_covariance_matrix_pred(TESTING_STOCKS)
print(covariance_matrix_pred)
# Out:
# [[1.38366256 0.72826517 1.14112161 ... 0.4838617  0.51981948 1.20447038]
#  [0.72826517 1.55246882 0.74385607 ... 0.19392819 0.09879106 1.07162827]
#  [1.14112161 0.74385607 1.43033425 ... 0.68568201 0.32407817 1.27502712]
#  ...
#  [0.4838617  0.19392819 0.68568201 ... 3.69281305 0.57842185 0.20027396]
#  [0.51981948 0.09879106 0.32407817 ... 0.57842185 0.80956287 0.14574575]
#  [1.20447038 1.07162827 1.27502712 ... 0.20027396 0.14574575 3.0329736 ]]

# %%
#################################################################################
# MARKOWITZ MODELS FUNCTIONS
# BUNDLED UP SIMPLE AND COMPLEX MARKOWITZ MODELS INTO TWO HELPER FUNCTIONS
#################################################################################
import numpy as np
from scipy.optimize import minimize

# Simple model
def calculate_markowitz_weights_simple(sigma_squared, expected_returns, covariance_matrix):

  def objective(weights, expected_returns):
    return -np.dot(weights, expected_returns)

  # Weights must be between 0 and 1
  bounds = tuple((0, 1) for _ in range(len(expected_returns)))

  # Initial guess for weights
  initial_guess = np.ones(len(expected_returns)) / len(expected_returns) # [1/5, 1/5, etc.]

  constraint = ({'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1})

  result = minimize(objective, initial_guess, args=(expected_returns,), method='SLSQP', bounds=bounds, constraints=constraint)
  optimal_weights_complex = result.x
  return optimal_weights_complex

# Complex model
def calculate_markowitz_weights_complex(sigma_squared, expected_returns, covariance_matrix):

  def objective(weights, expected_returns):
    return -np.dot(weights, expected_returns)

  # Set bounds for individual weights (0 <= weight <= 1)
  bounds = tuple((0, 1) for _ in range(len(expected_returns)))

  # Initial guess for weights
  initial_guess = np.ones(len(expected_returns)) / len(expected_returns) # [1/5, 1/5, etc.]

  # Constraints
  constraint_1 = ({'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1})
  constraint_2 = {'type': 'ineq', 'fun': lambda weights: sigma_squared - np.dot(weights.T, np.dot(covariance_matrix, weights))}
  constraints = [constraint_1, constraint_2]

  result = minimize(objective, initial_guess, args=(expected_returns,), method='SLSQP', bounds=bounds, constraints=constraints)
  optimal_weights_complex = result.x
  return optimal_weights_complex

# %%
######################################################################
# Running each of the 4 combinations for BOTH simple AND complex (31424)
######################################################################
all_weights_simple = []
all_weights_complex = []
covariance_matrix_historical = calculate_covariance_matrix_hist(TESTING_STOCKS)
covariance_matrix_pred = calculate_covariance_matrix_pred(TESTING_STOCKS)

expected_returns = [expected_returns_ridge, expected_returns_SMA_1] # changed from expected_returns_SMA to expected_returns_SMA_1
covariances = [covariance_matrix_historical, covariance_matrix_pred]

for i in range(len(expected_returns)):
  exp_vec = expected_returns[i]
  for j in range(len(covariances)):
    cov_matrix = covariances[j]
    weights_simple = calculate_markowitz_weights_simple(0.15, exp_vec, cov_matrix)
    weights_complex = calculate_markowitz_weights_complex(0.15, exp_vec, cov_matrix)
    all_weights_simple.append(weights_simple)
    all_weights_complex.append(weights_complex)

print(all_weights_simple)
print(all_weights_complex) # So far, this looks correct
# Out:
# [array([0.00000000e+00, 0.00000000e+00, 2.14230131e-15, 0.00000000e+00,
#        2.96026405e-15, 3.16413562e-15, 2.15966173e-15, 1.20940127e-15,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.26342378e-15, 0.00000000e+00, 0.00000000e+00, 5.98914187e-16,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 3.07591236e-15, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.27978743e-16, 0.00000000e+00,
#        3.87884285e-15, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 5.73325086e-16, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.61094545e-16]), array([0.00000000e+00, 0.00000000e+00, 2.14230131e-15, 0.00000000e+00,
#        2.96026405e-15, 3.16413562e-15, 2.15966173e-15, 1.20940127e-15,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.26342378e-15, 0.00000000e+00, 0.00000000e+00, 5.98914187e-16,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 3.07591236e-15, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.27978743e-16, 0.00000000e+00,
#        3.87884285e-15, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 5.73325086e-16, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.61094545e-16]), array([2.07230066e-14, 5.31796829e-14, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00,
#        1.11877563e-03, 8.86279168e-02, 9.06875712e-02, 2.76948754e-01,
#        7.22100183e-12, 1.10003612e-01, 9.28863581e-12, 1.47522245e-13,
#        1.35973706e-11, 7.49499579e-13, 3.49815328e-16, 1.69116195e-12,
#        3.99332055e-12, 2.03443192e-12, 5.53491289e-12, 3.56210568e-14,
#        1.54917464e-02, 8.58851732e-14, 4.04973143e-02, 2.01818751e-02,
#        3.57541235e-12, 6.63978562e-12, 2.79631683e-16, 1.47259548e-11,
#        1.81054776e-13, 3.20644358e-12]), array([3.13234807e-14, 7.32406843e-02, 3.33378855e-12, 5.42354748e-12,
#        1.16928690e-11, 9.56729878e-12, 3.62231242e-12, 6.00948033e-15,
#        1.34305841e-14, 7.53533999e-12, 2.59052012e-14, 4.49569533e-15,
#        3.02338491e-14, 1.85848162e-14, 2.80332243e-12, 6.04695643e-02,
#        3.96751300e-15, 1.43936195e-12, 1.02730421e-01, 1.04567494e-14,
#        1.95231665e-01, 1.89348711e-12, 1.61418987e-12, 3.93001638e-01,
#        1.26429298e-14, 5.65575652e-02, 2.36075347e-14, 1.36493755e-14,
#        3.65107807e-12, 2.46218443e-14, 2.27775158e-12, 2.25461044e-12,
#        1.83232141e-14, 1.07436888e-12, 1.35286405e-12, 3.26756033e-12,
#        2.93454831e-14, 1.35474208e-11, 8.19790189e-02, 3.67894482e-02,
#        8.97432989e-13, 1.41096356e-14, 2.32750288e-12, 1.79631919e-14,
#        9.62913356e-15, 6.64074643e-14]), array([2.18501348e-15, 1.73040140e-02, 5.76960514e-13, 1.42175544e-15,
#        2.78713208e-11, 1.36405213e-10, 8.08321885e-15, 6.69592656e-12,
#        1.41653792e-15, 1.07662641e-11, 7.66731376e-14, 2.64470292e-13,
#        2.73798940e-01, 8.59789850e-15, 2.14621485e-15, 6.53563641e-02,
#        5.91488862e-12, 5.88946717e-12, 2.48160262e-15, 1.69572798e-13,
#        1.11509649e-03, 8.86626439e-02, 9.06736490e-02, 2.76920604e-01,
#        2.33103324e-15, 1.09997240e-01, 4.51311978e-12, 1.12816496e-14,
#        3.00236078e-15, 3.09347690e-13, 1.28483189e-11, 6.88260901e-15,
#        3.43669966e-14, 7.15824222e-12, 1.15832016e-11, 1.71050633e-13,
#        1.54916148e-02, 7.79173451e-14, 4.05026736e-02, 2.01771680e-02,
#        8.70949013e-14, 9.46574779e-12, 6.41995184e-12, 5.63921325e-15,
#        1.74261944e-15, 5.57134021e-11])]

# %%
##############################################################################################################
# Evaluating the performance of each of the the Markowitz weights for BOTH the complex and simple models (31424)
# After obtaining weights, check the return of the model over the past 5 years
# if you invested at time t = 2018.
##############################################################################################################
END_DATE = "2018-12-28"
PREDICTION_END_DATE = "2023-12-28"
# We will assume we have a weights vector for each stock in the TESTING_STOCKS
#optimal_weights = # vector, we got this from running Markowitz model
optimal_weights_simple = all_weights_simple
optimal_weights_complex = all_weights_complex

def get_actual_returns(TESTING_STOCKS):
  actual_returns_testing = []
  for i in range(len(TESTING_STOCKS)):
    stock = TESTING_STOCKS[i]
    # Grab beginning value (Dec 28 2018)
    beginning_val = testing_data["Adj Close"][stock][END_DATE]
    ending_val = testing_y[i]
    ret = ((ending_val - beginning_val) / beginning_val) * 100
    actual_returns_testing.append(ret)
  return actual_returns_testing

def calculate_portfolio_return(weight_vec):
  actual_returns = get_actual_returns(TESTING_STOCKS)
  portfolio_return = weight_vec.dot(actual_returns)
  return portfolio_return

print("Markowitz model with 1 constraint")
print("Order: ridge-historical, ridge-pred, sma-historical, sma-pred")
for weight_vec in optimal_weights_simple:
  portfolio_return = calculate_portfolio_return(weight_vec)
  print(portfolio_return)

print("Markowitz model with 2 constraints")
print("Order: ridge-historical, ridge-pred, sma-historical, sma-pred")
for weight_vec in optimal_weights_complex:
  portfolio_return = calculate_portfolio_return(weight_vec)
  print(portfolio_return)
# Out:
# Markowitz model with 1 constraint
# Order: ridge-historical, ridge-pred, sma-historical, sma-pred
# 30.089232846481444
# 30.089232846481444
# 727.2166452666834
# 727.2166452666834
# Markowitz model with 2 constraints
# Order: ridge-historical, ridge-pred, sma-historical, sma-pred
# 49.80890414356125
# 44.74011310674608
# 49.80871109742626
# 44.741334854290535

# %%
###################################################################
# Nolawi's Thetas and Covariance Matrices
###################################################################
thetas = []
X_matr = []
cov_matr = []
all_ret = []

data = yf.download(ALL_STOCKS, start="2018-8-20", end="2023-11-30")

y_data = yf.download(ALL_STOCKS, start="2018-8-20", end="2023-11-30")["Adj Close"]

for i in range(60):

  testing_X_dict = make_feature_dict(ALL_STOCKS, data, GO_BACK)

  ret = []
  for stock in ALL_STOCKS:
    ret.append((data["Adj Close"][stock].iloc[-1] - data["Adj Close"][stock].iloc[-21]) / data["Adj Close"][stock].iloc[-21])
  all_ret.append(ret)

  daily_ret_unordered = data[-22:]["Adj Close"].pct_change()[-21:]

  daily_ret = np.array([daily_ret_unordered[stock] for stock in ALL_STOCKS])

  covariance_matrix = np.cov(daily_ret)

  cov_matr.append(covariance_matrix)

  data = data[:-21]

  training_X_dict = make_feature_dict(ALL_STOCKS, data, GO_BACK)

  testing_X = dict_to_matrix(testing_X_dict)

  training_X = dict_to_matrix(training_X_dict)

  n = training_X.shape[1]
  feature_norms = np.zeros(n)

  for i in range(n):
    col = training_X[:, i]
    feature_norms[i] = np.linalg.norm(col)

  training_X = training_X / feature_norms

  testing_X = testing_X / feature_norms

  X_matr.append(testing_X)

  training_y_unordered = y_data.iloc[-1]
  training_y = np.array([training_y_unordered[stock] for stock in ALL_STOCKS])

  y_data = y_data[:-21]

  thetas.append(ridge_obtain_thetas(training_X, training_y))


thetas = thetas[::-1]
X_matr = X_matr[::-1]
cov_matr = cov_matr[::-1]
all_ret = all_ret[::-1]

print(len(thetas))
print(len(X_matr))
print(len(cov_matr))
# Out:
# [*********************100%%**********************]  46 of 46 completed
# [*********************100%%**********************]  46 of 46 completed
# 60
# 60
# 60

# %%
print(cov_matr[0].shape)
# Out:
# (46, 46)

# %%
################################################################################
# NOLAWI'S CELL FOR Reinforcement Learning
################################################################################
import numpy as np
import tensorflow as tf

stocks = ALL_STOCKS

sigma_squared = 0.15

def calculate_reward(weights, feature_matrix, theta, covariance_matrix):
  weights = weights / np.linalg.norm(weights)
  if weights.T.dot(covariance_matrix.dot(weights)) > sigma_squared:
    return -1000
  return weights.T.dot(feature_matrix.dot(theta))


def get_reward(actions, weights, feature_matrix, theta, covariance_matrix):
  for i in range(len(actions)):
    if actions[i] == 0:
      weights[i] = np.random.rand()
  return calculate_reward(weights, feature_matrix, theta, covariance_matrix)


# Define the policy network
class PolicyNetwork(tf.keras.Model):
    def __init__(self):
        super(PolicyNetwork, self).__init__()
        self.dense = tf.keras.layers.Dense(units=2, activation='softmax')

    def call(self, state):
        return self.dense(state)

# Initialize policy network and optimizer
policy_network = PolicyNetwork()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

# Training loop
num_episodes = 200


best_weights = []
# for date in last_days_of_months:
for b in range(len(thetas)):

    weights = np.random.uniform(0,1,len(stocks))
    weights /= np.sum(weights)

    max_reward = -2000
    max_weights = weights
    for episode in range(num_episodes):
      # Initialize lists to store episode data
      episode_weights = []
      episode_actions = []
      episode_rewards = []
      episode_matrices = []

      action_probs = policy_network(X_matr[b])
      # print(X_matr[b])
      # print(action_probs)
      actions = []

      for i in range(len(stocks)):
        actions.append(np.random.choice(len(action_probs[i]), p=action_probs.numpy()[i]))

      actions = np.array(actions)

      # Take action and observe reward
      this_reward = get_reward(actions, weights, X_matr[b], thetas[b], cov_matr[b])
      if this_reward > max_reward:
        max_weights = weights
        max_reward = this_reward

        # Store state, action, and reward
      episode_weights.append(weights)
      episode_actions.append(actions)
      episode_rewards.append(this_reward)
      episode_matrices.append(X_matr[b])

      episode_rewards = np.array(episode_rewards)
        # Compute loss and update policy
      with tf.GradientTape() as tape:
            action_probs = policy_network(np.vstack(episode_matrices))

            action_masks = tf.one_hot(episode_actions, len(action_probs[0]))

            log_probs = tf.reduce_sum(action_masks * tf.math.log(action_probs), axis=1)
            loss = -tf.reduce_mean(log_probs * episode_rewards)

      gradients = tape.gradient(loss, policy_network.trainable_variables)
      optimizer.apply_gradients(zip(gradients, policy_network.trainable_variables))

    # Print episode information

      print(f"Iteration: {b} Episode: {episode}, Max Reward: {max_reward}")
      # print(len(episode_actions[0]))
    max_weights /= np.sum(max_weights)
    best_weights.append(max_weights)
print(best_weights)
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration: 37 Episode: 163, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 164, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 165, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 166, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 167, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 168, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 169, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 170, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 171, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 172, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 173, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 174, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 175, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 176, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 177, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 178, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 179, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 180, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 181, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 182, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 183, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 184, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 185, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 186, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 187, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 188, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 189, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 190, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 191, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 192, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 193, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 194, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 195, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 196, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 197, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 198, Max Reward: 756.1131165309026
# Iteration: 37 Episode: 199, Max Reward: 756.1131165309026
# Iteration: 38 Episode: 0, Max Reward: 666.7020182427339
# Iteration: 38 Episode: 1, Max Reward: 703.3823579899433
# Iteration: 38 Episode: 2, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 3, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 4, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 5, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 6, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 7, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 8, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 9, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 10, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 11, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 12, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 13, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 14, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 15, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 16, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 17, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 18, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 19, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 20, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 21, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 22, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 23, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 24, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 25, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 26, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 27, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 28, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 29, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 30, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 31, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 32, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 33, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 34, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 35, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 36, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 37, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 38, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 39, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 40, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 41, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 42, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 43, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 44, Max Reward: 821.0389957784581
# Iteration: 38 Episode: 45, Max Reward: 821.0389957784581
# Iteration: 38 Episode:
# Iteration: 39 Episode: 27, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 28, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 29, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 30, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 31, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 32, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 33, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 34, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 35, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 36, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 37, Max Reward: 859.3284643706337
# Iteration: 39 Episode: 38, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 39, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 40, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 41, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 42, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 43, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 44, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 45, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 46, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 47, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 48, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 49, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 50, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 51, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 52, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 53, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 54, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 55, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 56, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 57, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 58, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 59, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 60, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 61, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 62, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 63, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 64, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 65, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 66, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 67, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 68, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 69, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 70, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 71, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 72, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 73, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 74, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 75, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 76, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 77, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 78, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 79, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 80, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 81, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 82, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 83, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 84, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 85, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 86, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 87, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 88, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 89, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 90, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 91, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 92, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 93, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 94, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 95, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 96, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 97, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 98, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 99, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 100, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 101, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 102, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 103, Max Reward: 863.6496105129777
# Iteration: 39 Episode: 104, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 105, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 106, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 107, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 108, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 109, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 110, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 111, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 112, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 113, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 114, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 115, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 116, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 117, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 118, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 119, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 120, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 121, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 122, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 123, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 124, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 125, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 126, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 127, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 128, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 129, Max Reward: 865.9503347487627
# Iteration: 39 Episode: 130, Max Reward: 870.6398192279015
# Iteration: 39 Episode: 131, Max Reward: 870.6398192279015
# Iteration: 39 Episode: 132, Max Reward: 870.6398192279015
# Iteration: 39 Episode: 133, Max Reward: 870.6398192279015
# Iteration: 39 Episode: 186, Max Reward: 898.810584910929
# Iteration: 39 Episode: 187, Max Reward: 898.810584910929
# Iteration: 39 Episode: 188, Max Reward: 898.810584910929
# Iteration: 39 Episode: 189, Max Reward: 898.810584910929
# Iteration: 39 Episode: 190, Max Reward: 898.810584910929
# Iteration: 39 Episode: 191, Max Reward: 898.810584910929
# Iteration: 39 Episode: 192, Max Reward: 898.810584910929
# Iteration: 39 Episode: 193, Max Reward: 898.810584910929
# Iteration: 39 Episode: 194, Max Reward: 898.810584910929
# Iteration: 39 Episode: 195, Max Reward: 898.810584910929
# Iteration: 39 Episode: 196, Max Reward: 898.810584910929
# Iteration: 39 Episode: 197, Max Reward: 898.810584910929
# Iteration: 39 Episode: 198, Max Reward: 898.810584910929
# Iteration: 39 Episode: 199, Max Reward: 898.810584910929
# Iteration: 40 Episode: 0, Max Reward: 693.9918021797989
# Iteration: 40 Episode: 1, Max Reward: 693.9918021797989
# Iteration: 40 Episode: 2, Max Reward: 693.9918021797989
# Iteration: 40 Episode: 3, Max Reward: 693.9918021797989
# Iteration: 40 Episode: 4, Max Reward: 693.9918021797989
# Iteration: 40 Episode: 5, Max Reward: 693.9918021797989
# Iteration: 40 Episode: 6, Max Reward: 694.6753882918987
# Iteration: 40 Episode: 7, Max Reward: 694.6753882918987
# Iteration: 40 Episode: 8, Max Reward: 694.6753882918987
# Iteration: 40 Episode: 9, Max Reward: 694.6753882918987
# Iteration: 40 Episode: 10, Max Reward: 697.9185524269155
# Iteration: 40 Episode: 11, Max Reward: 697.9185524269155
# Iteration: 40 Episode: 12, Max Reward: 697.9185524269155
# Iteration: 40 Episode: 13, Max Reward: 697.9185524269155
# Iteration: 40 Episode: 14, Max Reward: 697.9185524269155
# Iteration: 40 Episode: 15, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 16, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 17, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 18, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 19, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 20, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 21, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 22, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 23, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 24, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 25, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 26, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 27, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 28, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 29, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 30, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 31, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 32, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 33, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 34, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 35, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 36, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 37, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 38, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 39, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 40, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 41, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 42, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 43, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 44, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 45, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 46, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 47, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 48, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 49, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 50, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 51, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 52, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 53, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 54, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 55, Max Reward: 701.2138072793911
# Iteration: 40 Episode: 56, Max Reward: 710.2770516075022
# Iteration: 40 Episode: 57, Max Reward: 710.2770516075022
# Iteration: 40 Episode: 58, Max Reward: 710.2770516075022
# Iteration: 40 Episode: 59, Max Reward: 710.2770516075022
# Iteration: 40 Episode: 60, Max Reward: 710.2770516075022
# Iteration: 40 Episode: 61, Max Reward: 710.2770516075022
# Iteration: 40 Episode: 62, Max Reward: 710.2770516075022
# Iteration: 40 Episode: 63, Max Reward: 710.2770516075022
# Iteration: 40 Episode: 64, Max Reward: 710.2770516075022
# Iteration: 40 Episode: 65, Max Reward: 710.2770516075022
# Iteration: 40 Episode: 66, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 67, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 68, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 69, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 70, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 71, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 72, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 73, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 74, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 75, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 76, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 77, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 78, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 79, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 80, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 81, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 82, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 83, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 84, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 85, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 86, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 87, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 88, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 89, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 90, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 91, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 92, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 93, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 94, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 95, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 96, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 97, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 98, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 99, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 100, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 101, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 102, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 103, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 104, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 105, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 106, Max Reward: 733.4871002721004
# Iteration: 40 Episode: 107, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 108, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 109, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 110, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 111, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 112, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 113, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 114, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 115, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 116, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 117, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 118, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 119, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 120, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 121, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 122, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 123, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 124, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 125, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 126, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 127, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 128, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 129, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 130, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 131, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 132, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 133, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 134, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 135, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 136, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 137, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 138, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 139, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 140, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 141, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 142, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 143, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 144, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 145, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 146, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 147, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 148, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 149, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 150, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 151, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 152, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 153, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 154, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 155, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 156, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 157, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 158, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 159, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 160, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 161, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 162, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 163, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 164, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 165, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 166, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 167, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 168, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 169, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 170, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 171, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 172, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 173, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 174, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 175, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 176, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 177, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 178, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 179, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 180, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 181, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 182, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 183, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 184, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 185, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 186, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 187, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 188, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 189, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 190, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 191, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 192, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 193, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 194, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 195, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 196, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 197, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 198, Max Reward: 734.8947733613845
# Iteration: 40 Episode: 199, Max Reward: 734.8947733613845
# Iteration: 41 Episode: 0, Max Reward: 678.1732372314461
# Iteration: 41 Episode: 1, Max Reward: 736.3077710879
# Iteration: 41 Episode: 2, Max Reward: 736.3077710879
# Iteration: 41 Episode: 3, Max Reward: 736.3077710879
# Iteration: 41 Episode: 4, Max Reward: 736.3077710879
# Iteration: 41 Episode: 5, Max Reward: 736.3077710879
# Iteration: 41 Episode: 6, Max Reward: 736.3077710879
# Iteration: 41 Episode: 7, Max Reward: 736.3077710879
# Iteration: 41 Episode: 8, Max Reward: 736.3077710879
# Iteration: 41 Episode: 9, Max Reward: 736.3077710879
# Iteration: 41 Episode: 10, Max Reward: 736.3077710879
# Iteration: 41 Episode: 11, Max Reward: 736.3077710879
# Iteration: 41 Episode: 12, Max Reward: 736.3077710879
# Iteration: 41 Episode: 13, Max Reward: 736.3077710879
# Iteration: 41 Episode: 14, Max Reward: 736.3077710879
# Iteration: 41 Episode: 15, Max Reward: 736.3077710879
# Iteration: 41 Episode: 16, Max Reward: 736.3077710879
# Iteration: 41 Episode: 17, Max Reward: 736.3077710879
# Iteration: 41 Episode: 18, Max Reward: 736.3077710879
# Iteration: 41 Episode: 19, Max Reward: 736.3077710879
# Iteration: 41 Episode: 20, Max Reward: 736.3077710879
# Iteration: 41 Episode: 21, Max Reward: 736.3077710879
# Iteration: 41 Episode: 22, Max Reward: 736.3077710879
# Iteration: 41 Episode: 23, Max Reward: 736.3077710879
# Iteration: 41 Episode: 24, Max Reward: 736.3077710879
# Iteration: 41 Episode: 25, Max Reward: 736.3077710879
# Iteration: 41 Episode: 26, Max Reward: 736.3077710879
# Iteration: 41 Episode: 27, Max Reward: 736.3077710879
# Iteration: 41 Episode: 28, Max Reward: 736.3077710879
# Iteration: 41 Episode: 29, Max Reward: 736.3077710879
# Iteration: 41 Episode: 30, Max Reward: 736.3077710879
# Iteration: 41 Episode: 31, Max Reward: 736.3077710879
# Iteration: 41 Episode: 32, Max Reward: 736.3077710879
# Iteration: 41 Episode: 33, Max Reward: 736.3077710879
# Iteration: 41 Episode: 34, Max Reward: 736.3077710879
# Iteration: 41 Episode: 35, Max Reward: 736.3077710879
# Iteration: 41 Episode: 36, Max Reward: 736.3077710879
# Iteration: 41 Episode: 37, Max Reward: 736.3077710879
# Iteration: 41 Episode: 38, Max Reward: 736.3077710879
# Iteration: 41 Episode: 39, Max Reward: 736.3077710879
# Iteration: 41 Episode: 40, Max Reward: 736.3077710879
# Iteration: 41 Episode: 41, Max Reward: 736.3077710879
# Iteration: 41 Episode: 42, Max Reward: 736.3077710879
# Iteration: 41 Episode: 43, Max Reward: 736.3077710879
# Iteration: 41 Episode: 44, Max Reward: 736.3077710879
# Iteration: 41 Episode: 45, Max Reward: 736.3077710879
# Iteration: 41 Episode: 46, Max Reward: 736.3077710879
# Iteration: 41 Episode: 47, Max Reward: 736.3077710879
# Iteration: 41 Episode: 48, Max Reward: 736.3077710879
# Iteration: 41 Episode: 49, Max Reward: 736.3077710879
# Iteration: 41 Episode: 50, Max Reward: 736.3077710879
# Iteration: 41 Episode: 51, Max Reward: 736.3077710879
# Iteration: 41 Episode: 52, Max Reward: 736.3077710879
# Iteration: 41 Episode: 53, Max Reward: 736.3077710879
# Iteration: 41 Episode: 54, Max Reward: 736.3077710879
# Iteration: 41 Episode: 55, Max Reward: 736.3077710879
# Iteration: 41 Episode: 56, Max Reward: 736.3077710879
# Iteration: 41 Episode: 57, Max Reward: 736.3077710879
# Iteration: 41 Episode: 58, Max Reward: 736.3077710879
# Iteration: 41 Episode: 59, Max Reward: 736.3077710879
# Iteration: 41 Episode: 60, Max Reward: 736.3077710879
# Iteration: 41 Episode: 61, Max Reward: 736.3077710879
# Iteration: 41 Episode: 62, Max Reward: 736.3077710879
# Iteration: 41 Episode: 63, Max Reward: 736.3077710879
# Iteration: 41 Episode: 64, Max Reward: 736.3077710879
# Iteration: 41 Episode: 65, Max Reward: 736.3077710879
# Iteration: 41 Episode: 66, Max Reward: 736.3077710879
# Iteration: 41 Episode: 67, Max Reward: 736.3077710879
# Iteration: 41 Episode: 68, Max Reward: 736.3077710879
# Iteration: 41 Episode: 69, Max Reward: 736.3077710879
# Iteration: 41 Episode: 70, Max Reward: 736.3077710879
# Iteration: 41 Episode: 71, Max Reward: 736.3077710879
# Iteration: 41 Episode: 72, Max Reward: 736.3077710879
# Iteration: 41 Episode: 73, Max Reward: 736.3077710879
# Iteration: 41 Episode: 74, Max Reward: 736.3077710879
# Iteration: 41 Episode: 75, Max Reward: 736.3077710879
# Iteration: 41 Episode: 76, Max Reward: 736.3077710879
# Iteration: 41 Episode: 77, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 78, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 79, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 80, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 81, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 82, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 83, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 84, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 85, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 86, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 87, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 88, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 89, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 90, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 91, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 92, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 93, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 94, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 95, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 96, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 97, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 98, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 99, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 100, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 101, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 102, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 103, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 104, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 105, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 106, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 107, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 108, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 109, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 110, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 111, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 112, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 113, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 114, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 115, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 116, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 117, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 118, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 119, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 120, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 121, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 122, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 123, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 124, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 125, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 126, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 127, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 128, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 129, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 130, Max Reward: 753.9334647158186
# Iteration: 41 Episode: 131, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 132, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 133, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 134, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 135, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 136, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 137, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 138, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 139, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 140, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 141, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 142, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 143, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 144, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 145, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 146, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 147, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 148, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 149, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 150, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 151, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 152, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 153, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 154, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 155, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 156, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 157, Max Reward: 757.5257260933668
# Iteration: 41 Episode: 158, Max Reward: 757.5257260933668
# Iteration: 41 Episode:
#        1.68596104e-02, 1.13867457e-02, 4.06401682e-02, 4.38956161e-02,
#        3.65682037e-02, 4.50686112e-02, 1.33409230e-02, 7.52396737e-03,
#        3.46097721e-04, 1.49050142e-02, 2.82709838e-02, 8.81109215e-03,
#        3.89591060e-02, 1.52204693e-05, 4.35338678e-02, 1.88577083e-02,
#        4.08995497e-02, 2.86289812e-02, 2.33980507e-03, 3.43646750e-02,
#        1.52363112e-03, 1.00042436e-02, 3.07292324e-02, 1.31812695e-05,
#        3.51074552e-02, 2.44014619e-02, 2.01024151e-02, 4.24749423e-03,
#        2.72009406e-02, 2.74107332e-02, 2.36108111e-02, 3.94865647e-02,
#        3.79058290e-02, 1.52056925e-02, 4.15503275e-02, 5.64950205e-03,
#        1.13832946e-02, 2.20141648e-03]), array([0.00671676, 0.02240209, 0.01914667, 0.02890443, 0.0053954 ,
#        0.00062924, 0.02262804, 0.01638385, 0.03718082, 0.01389172,
#        0.03655285, 0.01773015, 0.02989637, 0.03701799, 0.03562359,
#        0.02586687, 0.03199289, 0.00836979, 0.02940793, 0.03143492,
#        0.00671457, 0.00994008, 0.01656401, 0.00231127, 0.00062271,
#        0.03820304, 0.01840515, 0.00566161, 0.01251697, 0.01284067,
#        0.01915406, 0.02755362, 0.0285141 , 0.0184647 , 0.02419977,
#        0.03008043, 0.03296886, 0.00710727, 0.03249279, 0.03895256,
#        0.01953642, 0.03696568, 0.00736313, 0.02965317, 0.03518553,
#        0.03085548]), array([0.01135224, 0.00497288, 0.04112006, 0.02153565, 0.0084873 ,
#        0.02615212, 0.00454913, 0.00243367, 0.02956911, 0.02251585,
#        0.0320857 , 0.03899744, 0.00178493, 0.03790029, 0.01738375,
#        0.04008116, 0.01467151, 0.01918569, 0.02054252, 0.03532937,
#        0.03422012, 0.0291527 , 0.01411774, 0.02861888, 0.00043656,
#        0.0061694 , 0.02262623, 0.0296897 , 0.02043412, 0.03490409,
#        0.04001856, 0.03349825, 0.03974782, 0.02177465, 0.01399985,
#        0.01211145, 0.02400027, 0.0196048 , 0.01324786, 0.0302061 ,
#        0.01339071, 0.00748463, 0.02323445, 0.00081376, 0.03505115,
#        0.02079577]), array([0.03016524, 0.02540072, 0.0427369 , 0.01019627, 0.02658706,
#        0.03106449, 0.00306447, 0.00463646, 0.02403339, 0.03452298,
#        0.0385424 , 0.01911087, 0.03685806, 0.01296181, 0.04071284,
#        0.00686359, 0.02312368, 0.01978529, 0.00563002, 0.03541976,
#        0.01298489, 0.03487423, 0.01655501, 0.01215979, 0.00141422,
#        0.02927731, 0.02044849, 0.00789125, 0.00071388, 0.03262655,
#        0.03489066, 0.03855054, 0.00267626, 0.04248642, 0.02208685,
#        0.00912055, 0.00816245, 0.02113923, 0.03953936, 0.00686119,
#        0.01168002, 0.04253154, 0.02364477, 0.03348577, 0.01110934,
#        0.01167315])]

# %%
best_weights = np.array(best_weights)
all_ret = np.array(all_ret)
portfolio_returns_RL = sum([w.T.dot(r) for w, r in zip(best_weights, all_ret)])
print(portfolio_returns_RL)
# Out:
# 0.7139087028396547
